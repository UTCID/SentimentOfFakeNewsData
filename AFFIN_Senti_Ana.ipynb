# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from afinn import Afinn

#Create Afinn analyzer target
af = Afinn()

# %%
##Read dataset
df = pd.read_excel("DataInputs/Liar.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/Liar-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#          label                                          statement
# 0        False  Says the Annies List political group supports ...
# 1    half-true  When did the decline of coal start? It started...
# 2  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 3        False  Health care reform legislation is likely to ma...
# 4    half-true  The economic turnaround started at the end of ...
#
# Data with sentiments:
#          label                                          statement  \
# 0        False  Says the Annies List political group supports ...
# 1    half-true  When did the decline of coal start? It started...
# 2  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 3        False  Health care reform legislation is likely to ma...
# 4    half-true  The economic turnaround started at the end of ...
#
#    Sentiment_score Sentiment_category
# 0              1.0                  P
# 1              1.0                  P
# 2              2.0                  P
# 3              3.0                  P
# 4              0.0                Neu
#
# 2d Tab between sentiments and truth:
# label               False  True  barely-true  half-true  mostly-true  \
# Sentiment_category
# N                     783   658          701        960          861
# Neu                  1065   862          782        961          958
# P                     659   533          620        706          635
#
# label               pants-fire
# Sentiment_category
# N                          375
# Neu                        404
# P                          268
#
# 2d Tab between sentiments and truth:
# label               False  True  barely-true  half-true  mostly-true  \
# Sentiment_category
# N                     783   658          701        960          861
# Neu                  1065   862          782        961          958
# P                     659   533          620        706          635
#
# label               pants-fire
# Sentiment_category
# N                          375
# Neu                        404
# P                          268
#
# 2d Tab for probility
# label                  False      True  barely-true  half-true  mostly-true  \
# Sentiment_category
# N                   0.312325  0.320507     0.333333   0.365436     0.350856
# Neu                 0.424811  0.419873     0.371850   0.365817     0.390383
# P                   0.262864  0.259620     0.294817   0.268748     0.258761
#
# label               pants-fire
# Sentiment_category
# N                     0.358166
# Neu                   0.385864
# P                     0.255969

# %%
##Read dataset
df = pd.read_excel("DataInputs/TJI-B.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/TJI-Buzzfeed-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#    label                                          statement
# 0  False  Donald Trump Caught Snorting Cocaine by Hotel ...
# 1  False  Donald Trump Hires Clueless Stacey Dash for Ne...
# 2  False  Donald Trump Meets With WWE Owner Vince McMaho...
# 3  False  Donald Trump Picks Stacey Dash as His Vice Pre...
# 4  False  Donald Trump Protester Speaks Out "I Was Paid ...
#
# Data with sentiments:
#    label                                          statement  Sentiment_score  \
# 0  False  Donald Trump Caught Snorting Cocaine by Hotel ...              0.0
# 1  False  Donald Trump Hires Clueless Stacey Dash for Ne...              0.0
# 2  False  Donald Trump Meets With WWE Owner Vince McMaho...              0.0
# 3  False  Donald Trump Picks Stacey Dash as His Vice Pre...              0.0
# 4  False  Donald Trump Protester Speaks Out "I Was Paid ...             -2.0
#
#   Sentiment_category
# 0                Neu
# 1                Neu
# 2                Neu
# 3                Neu
# 4                  N
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                      12     19
# Neu                    18     23
# P                       8     11
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                      12     19
# Neu                    18     23
# P                       8     11
#
# 2d Tab for probility
# label                  False     True
# Sentiment_category
# N                   0.315789  0.358491
# Neu                 0.473684  0.433962
# P                   0.210526  0.207547

# %%
##Read dataset
df = pd.read_excel("DataInputs/TJI-R.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/TJI-Random-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#    label                                          statement
# 0  False  How Obama Used The DOJ To Destroy A Reporter’s...
# 1  False  BREAKING – Trump DEFIES Obama, Tells Americans...
# 2  False  Turkey’s Erdogan Says U.S. Supports ISIL: ‘We ...
# 3  False  Egyptian paper: Transcript proves Kerry plotte...
# 4  False  Obama’s Racist Attacks Against White Working C...
#
# Data with sentiments:
#    label                                          statement  Sentiment_score  \
# 0  False  How Obama Used The DOJ To Destroy A Reporter’s...             -3.0
# 1  False  BREAKING – Trump DEFIES Obama, Tells Americans...              0.0
# 2  False  Turkey’s Erdogan Says U.S. Supports ISIL: ‘We ...              2.0
# 3  False  Egyptian paper: Transcript proves Kerry plotte...              2.0
# 4  False  Obama’s Racist Attacks Against White Working C...             -6.0
#
#   Sentiment_category
# 0                  N
# 1                Neu
# 2                  P
# 3                  P
# 4                  N
#
# 2d Tab between sentiments and truth:
# label               False  True  satire
# Sentiment_category
# N                      36    21      24
# Neu                    22    40      32
# P                      17    14      19
#
# 2d Tab between sentiments and truth:
# label               False  True  satire
# Sentiment_category
# N                      36    21      24
# Neu                    22    40      32
# P                      17    14      19
#
# 2d Tab for probility
# label                  False      True    satire
# Sentiment_category
# N                   0.480000  0.280000  0.320000
# Neu                 0.293333  0.533333  0.426667
# P                   0.226667  0.186667  0.253333

# %%
##Read dataset
df = pd.read_excel("DataInputs/FNN-P.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/FNN-Politifact-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#    label                                          statement
# 0  False                                    accessed Aug 11
# 1  False   Actress Emma Stone â€˜For the first time in h...
# 2  False   BREAKING Muslimsâ€™ Disturbing Plan Comes Out...
# 3  False   Breaking President Trump makes English the of...
# 4  False   Friendly Fire â€¦ Charlottesville Car attacke...
#
# Data with sentiments:
#    label                                          statement  Sentiment_score  \
# 0  False                                    accessed Aug 11              0.0
# 1  False   Actress Emma Stone â€˜For the first time in h...              0.0
# 2  False   BREAKING Muslimsâ€™ Disturbing Plan Comes Out...             -2.0
# 3  False   Breaking President Trump makes English the of...              1.0
# 4  False   Friendly Fire â€¦ Charlottesville Car attacke...              1.0
#
#   Sentiment_category
# 0                Neu
# 1                Neu
# 2                  N
# 3                  P
# 4                  P
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                     211     96
# Neu                   165    431
# P                      56     97
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                     211     96
# Neu                   165    431
# P                      56     97
#
# 2d Tab for probility
# label                  False     True
# Sentiment_category
# N                   0.488426  0.153846
# Neu                 0.381944  0.690705
# P                   0.129630  0.155449

# %%
##Read dataset
df = pd.read_excel("DataInputs/FNN-G.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/FNN-GossipCop-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#    label                                          statement
# 0  False      Kendall   Kylie Jenner Jenner NOT Upset Up...
# 1  False      Kim Kardashian Dethroned Dethroned By Khlo...
# 2  False      Kim Kardashian Did NOT Hot Staffer Hot Sta...
# 3  False      The Voice The Voice Team NOT Surprised Sur...
# 4  False     Drake NOT Angelina Jolie s Toy Boy Toy Boy ...
#
# Data with sentiments:
#    label                                          statement  Sentiment_score  \
# 0  False      Kendall   Kylie Jenner Jenner NOT Upset Up...             -4.0
# 1  False      Kim Kardashian Dethroned Dethroned By Khlo...              0.0
# 2  False      Kim Kardashian Did NOT Hot Staffer Hot Sta...              4.0
# 3  False      The Voice The Voice Team NOT Surprised Sur...              0.0
# 4  False     Drake NOT Angelina Jolie s Toy Boy Toy Boy ...             -2.0
#
#   Sentiment_category
# 0                  N
# 1                Neu
# 2                  P
# 3                Neu
# 4                  N
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                    1405   3609
# Neu                  2689   7604
# P                    1229   5592
#
# 2d Tab between sentiments and truth:
# label               False  True
# Sentiment_category
# N                    1405   3609
# Neu                  2689   7604
# P                    1229   5592
#
# 2d Tab for probility
# label                  False     True
# Sentiment_category
# N                   0.263949  0.214758
# Neu                 0.505166  0.452484
# P                   0.230885  0.332758

# %%
##Read dataset
df = pd.read_excel("DataInputs/TVS-P.xlsx")
print("Original data:")
print(df.head())
print()

#Create Afinn analyzer target
af = Afinn()

#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['Statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['Truth-Rating']), list(df['Statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/TVS-Politifact-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#    Truth-Rating                                          Statement
# 0             5  About 47 percent of able-bodied people in the ...
# 1             0  Says Dan Patrick has "called immigration into ...
# 2             1  In 2008, "only 54 percent of Latinos in Texas ...
# 3             0  Even after Obamacare is fully implemented, the...
# 4             2  McDonald's in England only sells organic milk ...
#
# Data with sentiments:
#   label                                          statement  Sentiment_score  \
# 0     5  About 47 percent of able-bodied people in the ...              0.0
# 1     0  Says Dan Patrick has "called immigration into ...             -2.0
# 2     1  In 2008, "only 54 percent of Latinos in Texas ...              0.0
# 3     0  Even after Obamacare is fully implemented, the...              0.0
# 4     2  McDonald's in England only sells organic milk ...              1.0
#
#   Sentiment_category
# 0                Neu
# 1                  N
# 2                Neu
# 3                Neu
# 4                  P
#
# 2d Tab between sentiments and truth:
# label                 0    1    2    3    4    5
# Sentiment_category
# N                   569  674  779  555  630  307
# Neu                 753  804  788  640  805  333
# P                   458  525  585  522  529  227
#
# 2d Tab between sentiments and truth:
# label                 0    1    2    3    4    5
# Sentiment_category
# N                   569  674  779  555  630  307
# Neu                 753  804  788  640  805  333
# P                   458  525  585  522  529  227
#
# 2d Tab for probility
# label                      0         1         2         3         4         5
# Sentiment_category
# N                   0.319663  0.336495  0.361989  0.323238  0.320774  0.354095
# Neu                 0.423034  0.401398  0.366171  0.372743  0.409878  0.384083
# P                   0.257303  0.262107  0.271840  0.304019  0.269348  0.261822

# %%
##Read dataset
df = pd.read_excel("DataInputs/TVS-U.xlsx")
##drop unformat rows
df_c = df.drop(df[df.statement.apply(type)==float].index).copy()
df = df_c.drop(df_c[df_c.label.apply(type)==str].index).copy()
print("Original data:")
print(df.head())
print()


#Get sentiment score for each statement and category into 'Neu', 'P', 'N'
sent_scores_tb = [af.score(stat) for stat in df['statement']]
sent_category_tb = ['Neu' if score == 0
                        else 'P' if score > 0
                            else 'N' 
                                for score in sent_scores_tb]

#create new dataFrame with sentiment score and category
df_sent = pd.DataFrame([list(df['label']), list(df['statement']), sent_scores_tb, sent_category_tb]).T
df_sent.columns = ['label', 'statement', 'Sentiment_score', 'Sentiment_category']
df_sent['Sentiment_score'] = df_sent.Sentiment_score.astype('float')
print("Data with sentiments:")
print(df_sent.head())
print()
#output DataFrame to xlsx file as new data set
df_sent.to_excel('AFINN_Output/TVS-Unreliable-Affin.xlsx')

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = pd.crosstab(df_sent['label'], df_sent['Sentiment_category']).T
print("2d Tab between sentiments and truth: ")
print(df_sent_tab)
print()

#Below are to get statistic results for sentiments and labels
#Generate new data with number for each category for probability calculation
df_sent_tab = (pd.crosstab(df_sent['label'], df_sent['Sentiment_category']))
print("2d Tab between sentiments and truth: ")
print(df_sent_tab.T)
print()

#calculate the probility as sum of all is cancelled for num and den only use entry to div sum of each column
df = df_sent_tab.copy()
cols = df.columns
df[cols] = df[cols].div(df[cols].sum(axis=1), axis=0)
df = df.transpose()
print("2d Tab for probility ")
print(df)
print()
# Out:
# Original data:
#   label                                          statement
# 0     1  A little less than a decade ago, hockey fans w...
# 1     1  The writers of the HBO series The Sopranos too...
# 2     1  Despite claims from the TV news outlet to offe...
# 3     1  After receiving 'subpar' service and experienc...
# 4     1  After watching his beloved Seattle Mariners pr...
#
# Data with sentiments:
#   label                                          statement  Sentiment_score  \
# 0     1  A little less than a decade ago, hockey fans w...             19.0
# 1     1  The writers of the HBO series The Sopranos too...             -1.0
# 2     1  Despite claims from the TV news outlet to offe...             -8.0
# 3     1  After receiving 'subpar' service and experienc...             59.0
# 4     1  After watching his beloved Seattle Mariners pr...              6.0
#
#   Sentiment_category
# 0                  P
# 1                  N
# 2                  N
# 3                  P
# 4                  P
#
# 2d Tab between sentiments and truth:
# label                  1     2      3     4
# Sentiment_category
# N                   5828  4538  11073  4152
# Neu                  584   226   1621   481
# P                   7635  2178   5176  5360
#
# 2d Tab between sentiments and truth:
# label                  1     2      3     4
# Sentiment_category
# N                   5828  4538  11073  4152
# Neu                  584   226   1621   481
# P                   7635  2178   5176  5360
#
# 2d Tab for probility
# label                      1         2         3         4
# Sentiment_category
# N                   0.414893  0.653702  0.619642  0.415491
# Neu                 0.041575  0.032555  0.090711  0.048134
# P                   0.543532  0.313742  0.289647  0.536375
